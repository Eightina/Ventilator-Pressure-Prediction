# %%
import ray
ray.init()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in _connect(self)
#     602                 # connect
# --> 603                 sock.connect(socket_address)
#     604
#
# ConnectionRefusedError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\SEELEA~1\AppData\Local\Temp/ipykernel_25104/112003020.py in <module>
#       1 import ray
# ----> 2 ray.init()
#
# D:\programs\envs\python38\lib\site-packages\ray\_private\client_mode_hook.py in wrapper(*args, **kwargs)
#      80         if client_mode_should_convert():
#      81             return getattr(ray, func.__name__)(*args, **kwargs)
# ---> 82         return func(*args, **kwargs)
#      83
#      84     return wrapper
#
# D:\programs\envs\python38\lib\site-packages\ray\worker.py in init(address, num_cpus, num_gpus, resources, object_store_memory, local_mode, ignore_reinit_error, include_dashboard, dashboard_host, dashboard_port, job_config, configure_logging, logging_level, logging_format, log_to_driver, namespace, runtime_env, _enable_object_reconstruction, _redis_max_memory, _plasma_directory, _node_ip_address, _driver_object_store_memory, _memory, _redis_password, _temp_dir, _lru_evict, _metrics_export_port, _system_config, _tracing_startup_hook, **kwargs)
#     890         # handler. We still spawn a reaper process in case the atexit handler
#     891         # isn't called.
# --> 892         _global_node = ray.node.Node(
#     893             head=True,
#     894             shutdown_at_exit=False,
#
# D:\programs\envs\python38\lib\site-packages\ray\node.py in __init__(self, ray_params, head, shutdown_at_exit, spawn_reaper, connect_only)
#     246         # Start processes.
#     247         if head:
# --> 248             self.start_head_processes()
#     249             redis_client = self.create_redis_client()
#     250             redis_client.set("session_name", self.session_name)
#
# D:\programs\envs\python38\lib\site-packages\ray\node.py in start_head_processes(self)
#     892         assert self._redis_address is None
#     893         # If this is the head node, start the relevant head node processes.
# --> 894         self.start_redis()
#     895
#     896         self.start_gcs_server()
#
# D:\programs\envs\python38\lib\site-packages\ray\node.py in start_redis(self)
#     700
#     701         (self._redis_address, redis_shards,
# --> 702          process_infos) = ray._private.services.start_redis(
#     703              self._node_ip_address,
#     704              redis_log_files,
#
# D:\programs\envs\python38\lib\site-packages\ray\_private\services.py in start_redis(node_ip_address, redirect_files, resource_spec, port, redis_shard_ports, num_redis_shards, redis_max_clients, redirect_worker_output, password, fate_share, external_addresses, port_denylist)
#     867             num_retries = 1
#     868         # Start the primary Redis shard.
# --> 869         port, p = _start_redis_instance(
#     870             redis_executable,
#     871             port=port,
#
# D:\programs\envs\python38\lib\site-packages\ray\_private\services.py in _start_redis_instance(executable, port, redis_max_clients, num_retries, stdout_file, stderr_file, password, redis_max_memory, fate_share, port_denylist)
#    1027         host="127.0.0.1", port=port, password=password)
#    1028     # Wait for the Redis server to start.
# -> 1029     wait_for_redis_to_start("127.0.0.1", port, password=password)
#    1030     # Configure Redis to generate keyspace notifications. TODO(rkn): Change
#    1031     # this to only generate notifications for the export keys.
#
# D:\programs\envs\python38\lib\site-packages\ray\_private\services.py in wait_for_redis_to_start(redis_ip_address, redis_port, password)
#     653                 "Waiting for redis server at {}:{} to respond...".format(
#     654                     redis_ip_address, redis_port))
# --> 655             redis_client.client_list()
#     656         # If the Redis service is delayed getting set up for any reason, we may
#     657         # get a redis.ConnectionError: Error 111 connecting to host:port.
#
# D:\programs\envs\python38\lib\site-packages\redis\client.py in client_list(self, _type)
#    1192                                 client_types,))
#    1193             return self.execute_command('CLIENT LIST', b'TYPE', _type)
# -> 1194         return self.execute_command('CLIENT LIST')
#    1195
#    1196     def client_getname(self):
#
# D:\programs\envs\python38\lib\site-packages\redis\client.py in execute_command(self, *args, **options)
#     896         pool = self.connection_pool
#     897         command_name = args[0]
# --> 898         conn = self.connection or pool.get_connection(command_name, **options)
#     899         try:
#     900             conn.send_command(*args)
#
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in get_connection(self, command_name, *keys, **options)
#    1190         try:
#    1191             # ensure this connection is connected to Redis
# -> 1192             connection.connect()
#    1193             # connections that the pool provides should be ready to send
#    1194             # a command. if not, the connection was either returned to the
#
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in connect(self)
#     557             return
#     558         try:
# --> 559             sock = self._connect()
#     560         except socket.timeout:
#     561             raise TimeoutError("Timeout connecting to server")
#
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in _connect(self)
#     601
#     602                 # connect
# --> 603                 sock.connect(socket_address)
#     604
#     605                 # set the socket_timeout now that we're connected
#
# KeyboardInterrupt:

# %%
# import os
# os.environ["MODIN_ENGINE"] = "dask"  # Modin will use Dask

import modin.pandas as pd
import modin.pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tr = pd.read_csv('train.csv')
tr.describe()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in connect(self)
#     558         try:
# --> 559             sock = self._connect()
#     560         except socket.timeout:
#
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in _connect(self)
#     614         if err is not None:
# --> 615             raise err
#     616         raise socket.error("socket.getaddrinfo returned an empty list")
#
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in _connect(self)
#     602                 # connect
# --> 603                 sock.connect(socket_address)
#     604
#
# ConnectionRefusedError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# D:\programs\envs\python38\lib\site-packages\ray\_private\services.py in wait_for_redis_to_start(redis_ip_address, redis_port, password)
#     654                     redis_ip_address, redis_port))
# --> 655             redis_client.client_list()
#     656         # If the Redis service is delayed getting set up for any reason, we may
#
# D:\programs\envs\python38\lib\site-packages\redis\client.py in client_list(self, _type)
#    1193             return self.execute_command('CLIENT LIST', b'TYPE', _type)
# -> 1194         return self.execute_command('CLIENT LIST')
#    1195
#
# D:\programs\envs\python38\lib\site-packages\redis\client.py in execute_command(self, *args, **options)
#     897         command_name = args[0]
# --> 898         conn = self.connection or pool.get_connection(command_name, **options)
#     899         try:
#
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in get_connection(self, command_name, *keys, **options)
#    1191             # ensure this connection is connected to Redis
# -> 1192             connection.connect()
#    1193             # connections that the pool provides should be ready to send
#
# D:\programs\envs\python38\lib\site-packages\redis\connection.py in connect(self)
#     562         except socket.error as e:
# --> 563             raise ConnectionError(self._error_message(e))
#     564
#
# ConnectionError: Error 10061 connecting to 127.0.0.1:6379. 由于目标计算机积极拒绝，无法连接。.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# C:\Users\SEELEA~1\AppData\Local\Temp/ipykernel_25104/1360814762.py in <module>
# ----> 1 tr = pd.read_csv('train.csv')
#       2 tr.describe()
#
# D:\programs\envs\python38\lib\site-packages\modin\pandas\io.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     129     _, _, _, f_locals = inspect.getargvalues(inspect.currentframe())
#     130     kwargs = {k: v for k, v in f_locals.items() if k in _pd_read_csv_signature}
# --> 131     return _read(**kwargs)
#     132
#     133
#
# D:\programs\envs\python38\lib\site-packages\modin\pandas\io.py in _read(**kwargs)
#      56     from modin.data_management.factories.dispatcher import FactoryDispatcher
#      57
# ---> 58     Engine.subscribe(_update_engine)
#      59     pd_obj = FactoryDispatcher.read_csv(**kwargs)
#      60     # This happens when `read_csv` returns a TextFileReader object for iterating through
#
# D:\programs\envs\python38\lib\site-packages\modin\config\pubsub.py in subscribe(cls, callback)
#     211         """
#     212         cls._subs.append(callback)
# --> 213         callback(cls)
#     214
#     215     @classmethod
#
# D:\programs\envs\python38\lib\site-packages\modin\pandas\__init__.py in _update_engine(publisher)
#     111             from modin.engines.ray.utils import initialize_ray
#     112
# --> 113             initialize_ray()
#     114     elif publisher.get() == "Native":
#     115         # With OmniSci backend there is only a single worker per node
#
# D:\programs\envs\python38\lib\site-packages\modin\engines\ray\utils.py in initialize_ray(override_is_cluster, override_redis_address, override_redis_password)
#     172                 "_memory": object_store_memory,
#     173             }
# --> 174             ray.init(**ray_init_kwargs)
#     175
#     176         if Backend.get() == "Cudf":
#
# D:\programs\envs\python38\lib\site-packages\ray\_private\client_mode_hook.py in wrapper(*args, **kwargs)
#      80         if client_mode_should_convert():
#      81             return getattr(ray, func.__name__)(*args, **kwargs)
# ---> 82         return func(*args, **kwargs)
#      83
#      84     return wrapper
#
# D:\programs\envs\python38\lib\site-packages\ray\worker.py in init(address, num_cpus, num_gpus, resources, object_store_memory, local_mode, ignore_reinit_error, include_dashboard, dashboard_host, dashboard_port, job_config, configure_logging, logging_level, logging_format, log_to_driver, namespace, runtime_env, _enable_object_reconstruction, _redis_max_memory, _plasma_directory, _node_ip_address, _driver_object_store_memory, _memory, _redis_password, _temp_dir, _lru_evict, _metrics_export_port, _system_config, _tracing_startup_hook, **kwargs)
#     890         # handler. We still spawn a reaper process in case the atexit handler
#     891         # isn't called.
# --> 892         _global_node = ray.node.Node(
#     893             head=True,
#     894             shutdown_at_exit=False,
#
# D:\programs\envs\python38\lib\site-packages\ray\node.py in __init__(self, ray_params, head, shutdown_at_exit, spawn_reaper, connect_only)
#     246         # Start processes.
#     247         if head:
# --> 248             self.start_head_processes()
#     249             redis_client = self.create_redis_client()
#     250             redis_client.set("session_name", self.session_name)
#
# D:\programs\envs\python38\lib\site-packages\ray\node.py in start_head_processes(self)
#     892         assert self._redis_address is None
#     893         # If this is the head node, start the relevant head node processes.
# --> 894         self.start_redis()
#     895
#     896         self.start_gcs_server()
#
# D:\programs\envs\python38\lib\site-packages\ray\node.py in start_redis(self)
#     700
#     701         (self._redis_address, redis_shards,
# --> 702          process_infos) = ray._private.services.start_redis(
#     703              self._node_ip_address,
#     704              redis_log_files,
#
# D:\programs\envs\python38\lib\site-packages\ray\_private\services.py in start_redis(node_ip_address, redirect_files, resource_spec, port, redis_shard_ports, num_redis_shards, redis_max_clients, redirect_worker_output, password, fate_share, external_addresses, port_denylist)
#     867             num_retries = 1
#     868         # Start the primary Redis shard.
# --> 869         port, p = _start_redis_instance(
#     870             redis_executable,
#     871             port=port,
#
# D:\programs\envs\python38\lib\site-packages\ray\_private\services.py in _start_redis_instance(executable, port, redis_max_clients, num_retries, stdout_file, stderr_file, password, redis_max_memory, fate_share, port_denylist)
#    1027         host="127.0.0.1", port=port, password=password)
#    1028     # Wait for the Redis server to start.
# -> 1029     wait_for_redis_to_start("127.0.0.1", port, password=password)
#    1030     # Configure Redis to generate keyspace notifications. TODO(rkn): Change
#    1031     # this to only generate notifications for the export keys.
#
# D:\programs\envs\python38\lib\site-packages\ray\_private\services.py in wait_for_redis_to_start(redis_ip_address, redis_port, password)
#     667         except redis.ConnectionError as connEx:
#     668             if i >= num_retries - 1:
# --> 669                 raise RuntimeError(
#     670                     f"Unable to connect to Redis at {redis_ip_address}:"
#     671                     f"{redis_port} after {num_retries} retries. Check that "
#
# RuntimeError: Unable to connect to Redis at 127.0.0.1:6379 after 16 retries. Check that 127.0.0.1:6379 is reachable from this machine. If it is not, your firewall may be blocking this port. If the problem is a flaky connection, try setting the environment variable `RAY_START_REDIS_WAIT_RETRIES` to increase the number of attempts to ping the Redis server.
